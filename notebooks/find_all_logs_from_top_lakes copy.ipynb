# %%
import utils
from datetime import datetime
import pandas as pd

# %%
import importlib
import utils

importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\agand\\OneDrive\\Escritorio\\lakes\\lake-algae-analysis\\notebooks\\utils.py'>

# %%
data_directory = utils.get_data_directory()
top_lakes = pd.read_csv(f"{data_directory}/filtered_lakes.csv")

# %%
top_lakes
# Out:
#          osmid                       name          area       distance  \
# 0       332072  Maharana Pratap Reservoir  2.326225e+08   34042.231935
# 1       357472          Jalaput Reservoir  8.211214e+07  107375.805937
# 2      1579454           Yeleru Reservoir  4.753580e+07   44401.006783
# 3      1601368               Gobind Sagar  1.288780e+08   48946.638589
# 4      1606905                 Shabd Lake  9.741317e+05   35061.569722
# 5      1623305                        NaN  1.246895e+06   74127.271140
# 6      1624070               Pulicat Lake  5.605353e+08   69036.566401
# 7      2252564                  Man Sagar  1.091206e+06   32199.394088
# 8      2810519               Indira Sagar  7.018787e+08  131506.801830
# 9      5411363              Himayat Sagar  1.486924e+07    4929.035719
# 10     7876724                Singur Lake  1.332459e+08   78458.940502
# 11     7903593                        NaN  2.172984e+06   31631.873595
# ...

# %%
top_lake_logs = utils.get_all_saved_logs(top_lakes)
# Out:
# 0 :  252
# 1 :  186
# 2 :  186
# 3 :  126
# 4 :  22
# 5 :  31
# 6 :  31
# 7 :  24
# 8 :  23
# 9 :  190
# 10 :  173
# 11 :  179
# 12 :  186
# 13 :  220
# 14 :  249
# 15 :  180
# 16 :  173
# 17 :  180
# 18 :  183
# 19 :  183
# 20 :  177
# 21 :  181
# 22 :  183

# %%
top_lake_logs[top_lake_logs["exists_true_image"] == True]
# Out:
#            osmid         day  exists_true_image  total_pixel_area  \
# 2         332072  2020-01-03               True         233839575
# 3         332072  2020-01-08               True         233839575
# 4         332072  2020-01-13               True         233839575
# 5         332072  2020-01-18               True         233839575
# 6         332072  2020-01-23               True         233839575
# ...          ...         ...                ...               ...
# 3513  1273092884  2024-08-07               True           1076525
# 3514  1273092884  2024-08-17               True           1076525
# 3515  1273092884  2024-08-27               True           1076525
# 3516  1273092884  2024-09-01               True           1076525
# 3517  1273092884  2024-09-06               True           1076525
#
#        water_area   cloud_area  water_with_no_clouds_area  no_chl_area  \
# 2     214281000.0          0.0                214281000.0  174185325.0
# ...
